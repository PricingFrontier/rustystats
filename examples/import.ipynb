# %%
import polars as pl

# %%
pl.read_parquet('./frequency.parquet')
# Out:
# shape: (678_013, 12)
# ┌─────────┬──────────┬────────┬─────────┬───┬─────────┬────────────────────┬────────────┬──────────┐
# │ IDpol   ┆ VehPower ┆ VehAge ┆ DrivAge ┆ … ┆ Density ┆ Region             ┆ ClaimCount ┆ Exposure │
# │ ---     ┆ ---      ┆ ---    ┆ ---     ┆   ┆ ---     ┆ ---                ┆ ---        ┆ ---      │
# │ i64     ┆ i64      ┆ i64    ┆ i64     ┆   ┆ i64     ┆ str                ┆ i32        ┆ f64      │
# ╞═════════╪══════════╪════════╪═════════╪═══╪═════════╪════════════════════╪════════════╪══════════╡
# │ 1       ┆ 5        ┆ 0      ┆ 55      ┆ … ┆ 1217    ┆ Rhone-Alpes        ┆ 0          ┆ 0.1      │
# │ 3       ┆ 5        ┆ 0      ┆ 55      ┆ … ┆ 1217    ┆ Rhone-Alpes        ┆ 0          ┆ 0.77     │
# │ 5       ┆ 6        ┆ 2      ┆ 52      ┆ … ┆ 54      ┆ Picardie           ┆ 0          ┆ 0.75     │
# │ 10      ┆ 7        ┆ 0      ┆ 46      ┆ … ┆ 76      ┆ Aquitaine          ┆ 0          ┆ 0.09     │
# ...
