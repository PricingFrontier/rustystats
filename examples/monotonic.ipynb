# %%
import polars as pl

import rustystats as rs

data = pl.read_parquet("https://raw.githubusercontent.com/PricingFrontier/pricing-data-example/917c853e256df8d5814721ab56f72889a908bb08/data/processed/frequency_set.parquet")

train_data = data.filter(pl.col("Group") <= "3")
test_data = data.filter(pl.col("Group") == "4")
holdout_data = data.filter(pl.col("Group") == "5")

# %%
terms = {
    "BonusMalus": {"type": "bs", "monotonicity": "increasing"}
}

model = rs.glm_dict(
    response="ClaimCount",
    terms=terms,
    data=train_data,
    family="poisson",
    link="log",
    offset="Exposure",
).fit()

model.diagnostics(
    train_data=train_data,
    test_data = test_data,
    categorical_factors=["Region", "Area", "VehBrand", "VehGas"],
    continuous_factors=["VehPower", "VehAge", "DrivAge", "BonusMalus" ]
)
# Out:
# ModelDiagnostics(model_summary={'formula': 'ClaimCount ~ bs(BonusMalus, df=10)', 'family': 'poisson', 'link': 'log', 'n_obs': 406439, 'n_params': 11, 'df_resid': 406428, 'converged': True, 'iterations': 9}, train_test=TrainTestComparison(train=DatasetDiagnostics(dataset='train', n_obs=406439, total_exposure=214930.9, total_actual=21408.0, total_predicted=19604.16, loss=0.321978, deviance=130864.28, log_likelihood=-86205.97, aic=172433.93, gini=0.161, auc=0.5805, ae_ratio=1.092, ae_by_decile=[DecileMetrics(decile=1, n=40643, exposure=1621.4, actual=0.714198, predicted=0.087284, ae_ratio=8.1825), DecileMetrics(decile=2, n=40643, exposure=3518.54, actual=0.283356, predicted=0.097402, ae_ratio=2.9091), DecileMetrics(decile=3, n=40643, exposure=7369.3, actual=0.205854, predicted=0.088805, ae_ratio=2.318), DecileMetrics(decile=4, n=40643, exposure=11909.43, actual=0.141568, predicted=0.092097, ae_ratio=1.5372), DecileMetrics(decile=5, n=40643, exposure=17953.77, actual=0.108389, predicted=0.088424, ae_ratio=1.2258), DecileMetrics(decile=6, n=40643, exposure=23549.58, actual=0.100214, predicted=0.091714, ae_ratio=1.0927), DecileMetrics(decile=7, n=40643, exposure=30924.53, actual=0.086372, predicted=0.090093, ae_ratio=0.9587), DecileMetrics(decile=8, n=40643, exposure=40643.0, actual=0.053539, predicted=0.078558, ae_ratio=0.6815), DecileMetrics(decile=9, n=40643, exposure=38843.65, actual=0.062507, predicted=0.083279, ae_ratio=0.7506), DecileMetrics(decile=10, n=40652, exposure=38597.7, actual=0.115784, predicted=0.114191, ae_ratio=1.0139)], factor_diagnostics={'Region': [FactorLevelMetrics(level='Centre', n=96404, exposure=61624.29, actual=0.087952, predicted=0.089128, ae_ratio=0.9868, residual_mean=-0.188749), FactorLevelMetrics(level='Rhone-Alpes', n=50754, exposure=27166.77, actual=0.110724, predicted=0.092851, ae_ratio=1.1925, residual_mean=-0.15422), FactorLevelMetrics(level="Provence-Alpes-Cotes-D'Azur", n=47362, exposure=21355.34, actual=0.108497, predicted=0.091519, ae_ratio=1.1855, residual_mean=-0.14707), FactorLevelMetrics(level='Ile-de-France', n=41804, exposure=18109.61, actual=0.130152, predicted=0.095301, ae_ratio=1.3657, residual_mean=-0.126306), FactorLevelMetrics(level='Bretagne', n=25444, exposure=16746.97, actual=0.09554, predicted=0.089038, ae_ratio=1.073, residual_mean=-0.179738), FactorLevelMetrics(level='Pays-de-la-Loire', n=23339, exposure=13243.3, actual=0.093632, predicted=0.090607, ae_ratio=1.0334, residual_mean=-0.173891), FactorLevelMetrics(level='Nord-Pas-de-Calais', n=24081, exposure=11774.8, actual=0.089174, predicted=0.09192, ae_ratio=0.9701, residual_mean=-0.172585), FactorLevelMetrics(level='Languedoc-Roussillon', n=21388, exposure=8781.25, actual=0.102719, predicted=0.092369, ae_ratio=1.112, residual_mean=-0.148773), FactorLevelMetrics(level='Aquitaine', n=18645, exposure=8481.56, actual=0.094558, predicted=0.091488, ae_ratio=1.0336, residual_mean=-0.160751), FactorLevelMetrics(level='Poitou-Charentes', n=11400, exposure=6697.88, actual=0.086147, predicted=0.091399, ae_ratio=0.9425, residual_mean=-0.188425), FactorLevelMetrics(level='Midi-Pyrenees', n=10356, exposure=4255.99, actual=0.091166, predicted=0.092409, ae_ratio=0.9865, residual_mean=-0.157853), FactorLevelMetrics(level='Basse-Normandie', n=6581, exposure=3999.39, actual=0.089014, predicted=0.090312, ae_ratio=0.9856, residual_mean=-0.186074), FactorLevelMetrics(level='Bourgogne', n=6251, exposure=2989.63, actual=0.095664, predicted=0.092186, ae_ratio=1.0377, residual_mean=-0.162358), FactorLevelMetrics(level='Picardie', n=4817, exposure=2139.94, actual=0.125705, predicted=0.09664, ae_ratio=1.3008, residual_mean=-0.132621), FactorLevelMetrics(level='Haute-Normandie', n=5279, exposure=1889.46, actual=0.089973, predicted=0.093074, ae_ratio=0.9667, residual_mean=-0.149704), FactorLevelMetrics(level='Auvergne', n=3184, exposure=1406.19, actual=0.088182, predicted=0.091721, ae_ratio=0.9614, residual_mean=-0.167903), FactorLevelMetrics(level='L ...
